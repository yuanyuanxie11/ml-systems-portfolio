# %% [markdown]
# # Unified ML portfolio — notebooks
#
# This repo is **one project**: **ETL** → **analytics** (EDA, recommender, clustering, RFM) → **architecture** (see `docs/ETL_TO_ARCHITECTURE.md`, notebook `06`, and `docs/CUSTOMER_360_PLATFORM.md`).
#
# These notebooks call the same Python modules as the root-level CLIs (`run_*.py`, `clustering.py`). Run Jupyter from the **repository root** (parent of `notebooks/`), or rely on the `ROOT` cell below.

# %% [markdown]
# ## 01 — ETL / data loading

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
print("Repository root:", ROOT)

from netflix_recommender.data_io import run_data_loading
run_data_loading(ROOT, sample_fraction=1.0)  # 0.1 for dev
