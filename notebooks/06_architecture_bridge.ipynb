# %% [markdown]
# # 06 — Architecture bridge (read + link)
#
# This notebook has **no heavy compute**. It ties **Phase 1–2** (ETL + RFM / clustering / recommender) to **Phase 3** (how the same patterns show up on AWS at recommender scale and at Customer 360 scale).
#
# ## Read in this order
#
# 1. [`docs/ETL_TO_ARCHITECTURE.md`](../docs/ETL_TO_ARCHITECTURE.md) — short map from Parquet to segments to enterprise design.
# 2. [`ARCHITECTURE.md`](../ARCHITECTURE.md) — recommender serving on AWS (~$9.3K/mo @ 1M MAU, 150 ms p95).
# 3. [`docs/CUSTOMER_360_PLATFORM.md`](../docs/CUSTOMER_360_PLATFORM.md) — seven swim lanes, cost, SLOs, honest scope.
# 4. Open [`architecture/Customer360_Architecture.drawio`](../architecture/Customer360_Architecture.drawio) in [diagrams.net](https://app.diagrams.net/) (export PNG into the same folder when you want GitHub inline images).
#
# ## Optional: confirm outputs from Phase 2 exist
#
# Uncomment the cell below to list `outputs/` after you have run clustering and RFM.

# %% [markdown]
# ## Optional check

# %%
# from pathlib import Path
# root = Path.cwd().resolve().parent if not (Path.cwd() / 'outputs').exists() else Path.cwd()
# print(sorted(p.relative_to(root) for p in root.glob('outputs/**/*'))[:40])
print('Uncomment above after running notebooks 04–05.')
